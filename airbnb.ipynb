# %%
import pymongo
import pandas as pd
pd.set_option("display.max_columns",None)
import warnings
warnings.filterwarnings("ignore")
import json

# %%
Client=pymongo.MongoClient("mongodb+srv://saravanan:saravanan@cluster0.pk48nva.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")

db= Client["sample_airbnb"]
coll= db["listingsAndReviews"]

# %%
for i in coll.find():
    print(i)

# %%
data= []

for i in coll.find({},{"_id":1, "listing_url":1, "name":1, 'property_type':1, 'room_type':1, 'bed_type':1, 'minimum_nights':1, 'maximum_nights':1, 'cancellation_policy':1, 'accommodates':1, 'bedrooms':1, 'beds':1, 'number_of_reviews':1, 'bathrooms':1, 'price':1, 'extra_people':1, 'guests_included':1, 'images.picture_url':1, 'review_scores':1,'cleaning_fee':1}):
    data.append(i)

# %%
data

# %%
df_1= pd.DataFrame(data)

# %%
df_1.head()
# Out:
#         _id                            listing_url  \
# 0  10006546  https://www.airbnb.com/rooms/10006546
# 1  10009999  https://www.airbnb.com/rooms/10009999
# 2   1001265   https://www.airbnb.com/rooms/1001265
# 3  10021707  https://www.airbnb.com/rooms/10021707
# 4  10030955  https://www.airbnb.com/rooms/10030955
#
#                                name property_type        room_type  bed_type  \
# 0           Ribeira Charming Duplex         House  Entire home/apt  Real Bed
# 1      Horto flat with small garden     Apartment  Entire home/apt  Real Bed
# 2  Ocean View Waikiki Marina w/prkg   Condominium  Entire home/apt  Real Bed
# 3          Private Room in Bushwick     Apartment     Private room  Real Bed
# 4       Apt Linda Vista Lagoa - Rio     Apartment     Private room  Real Bed
#
#   minimum_nights maximum_nights          cancellation_policy  accommodates  \
# 0              2             30                     moderate             8
# 1              2           1125                     flexible             4
# 2              3            365  strict_14_with_grace_period             2
# 3             14           1125                     flexible             1
# 4              1           1125                     flexible             2
#
#    bedrooms  beds  number_of_reviews bathrooms   price cleaning_fee  \
# 0       3.0   5.0                 51       1.0   80.00        35.00
# 1       1.0   2.0                  0       1.0  317.00       187.00
# 2       1.0   1.0                 96       1.0  115.00       100.00
# 3       1.0   1.0                  1       1.5   40.00          NaN
# 4       1.0   1.0                  0       2.0  701.00       250.00
#
#   extra_people guests_included  \
# 0        15.00               6
# 1         0.00               1
# 2         0.00               1
# 3         0.00               1
# 4         0.00               1
#
#                                               images  \
# 0  {'picture_url': 'https://a0.muscache.com/im/pi...
# 1  {'picture_url': 'https://a0.muscache.com/im/pi...
# 2  {'picture_url': 'https://a0.muscache.com/im/pi...
# 3  {'picture_url': 'https://a0.muscache.com/im/pi...
# 4  {'picture_url': 'https://a0.muscache.com/im/pi...
#
#                                        review_scores
# 0  {'review_scores_accuracy': 9, 'review_scores_c...
# 1                                                 {}
# 2  {'review_scores_accuracy': 9, 'review_scores_c...
# 3  {'review_scores_accuracy': 10, 'review_scores_...
# 4                                                 {}

# %%
df_1["images"]= df_1["images"].apply(lambda x: x["picture_url"])

# %%
df_1["review_scores"]= df_1["review_scores"].apply(lambda x: x.get("review_scores_rating",0))

# %%
df_1.describe().T
# Out:
#                     count       mean        std  min  25%   50%   75%    max
# accommodates       5555.0   3.505851   2.297019  1.0  2.0   3.0   4.0   16.0
# bedrooms           5550.0   1.411712   1.041942  0.0  1.0   1.0   2.0   20.0
# beds               5542.0   2.071454   1.619660  0.0  1.0   2.0   3.0   25.0
# number_of_reviews  5555.0  27.606481  49.798376  0.0  1.0   5.0  32.0  533.0
# review_scores      5555.0  68.395680  41.829834  0.0  0.0  92.0  98.0  100.0

# %%
df_1.isnull().sum()
# Out:
# _id                       0
# listing_url               0
# name                      0
# property_type             0
# room_type                 0
# bed_type                  0
# minimum_nights            0
# maximum_nights            0
# cancellation_policy       0
# accommodates              0
# bedrooms                  5
# beds                     13
# number_of_reviews         0
# bathrooms                10
# price                     0
# cleaning_fee           1531
# extra_people              0
# guests_included           0
# images                    0
# review_scores             0
# dtype: int64

# %% [markdown]
# ## HANDLING THE NUL VALUES

# %%
# The Null Values Feauturs are 
#beds                     
#bedrooms                  
#bathrooms                
#cleaning_fee

# %%
df_1["beds"].fillna(0,inplace= True)
df_1["bedrooms"].fillna(0,inplace= True)
df_1["bathrooms"].fillna(0,inplace= True)
df_1["cleaning_fee"].fillna(0,inplace= True)

# %%
df_1.isnull().sum()
# Out:
# _id                    0
# listing_url            0
# name                   0
# property_type          0
# room_type              0
# bed_type               0
# minimum_nights         0
# maximum_nights         0
# cancellation_policy    0
# accommodates           0
# bedrooms               0
# beds                   0
# number_of_reviews      0
# bathrooms              0
# price                  0
# cleaning_fee           0
# extra_people           0
# guests_included        0
# images                 0
# review_scores          0
# dtype: int64

# %% [markdown]
# ## HANDLING THE DATA TYPES

# %%
df_1.head(2)
# Out:
#         _id                            listing_url  \
# 0  10006546  https://www.airbnb.com/rooms/10006546
# 1  10009999  https://www.airbnb.com/rooms/10009999
#
#                            name property_type        room_type  bed_type  \
# 0       Ribeira Charming Duplex         House  Entire home/apt  Real Bed
# 1  Horto flat with small garden     Apartment  Entire home/apt  Real Bed
#
#   minimum_nights maximum_nights cancellation_policy  accommodates  bedrooms  \
# 0              2             30            moderate             8       3.0
# 1              2           1125            flexible             4       1.0
#
#    beds  number_of_reviews bathrooms   price cleaning_fee extra_people  \
# 0   5.0                 51       1.0   80.00        35.00        15.00
# 1   2.0                  0       1.0  317.00       187.00         0.00
#
#   guests_included                                             images  \
# 0               6  https://a0.muscache.com/im/pictures/e83e702f-e...
# 1               1  https://a0.muscache.com/im/pictures/5b408b9e-4...
#
#    review_scores
# 0             89
# 1              0

# %%
df_1.dtypes
# Out:
# _id                     object
# listing_url             object
# name                    object
# property_type           object
# room_type               object
# bed_type                object
# minimum_nights          object
# maximum_nights          object
# cancellation_policy     object
# accommodates             int64
# bedrooms               float64
# beds                   float64
# number_of_reviews        int64
# bathrooms               object
# price                   object
# cleaning_fee            object
# extra_people            object
# guests_included         object
# images                  object
# review_scores            int64
# dtype: object

# %%
df_1["minimum_nights"]= df_1["minimum_nights"].astype(int)
df_1["maximum_nights"]= df_1["maximum_nights"].astype(int)
df_1["bedrooms"]= df_1["bedrooms"].astype(int)
df_1["beds"]= df_1["beds"].astype(int)
df_1["bathrooms"]= df_1["bathrooms"].astype(str).astype(float).astype(int)
df_1["price"]= df_1["price"].astype(str).astype(float).astype(int)
df_1["extra_people"]= df_1["extra_people"].astype(str).astype(float).astype(int)
df_1["guests_included"]= df_1["guests_included"].astype(str).astype(float).astype(int)
df_1["cleaning_fee"]= df_1["cleaning_fee"].astype(str).astype(float).astype(int)

# %%
df_1.dtypes
# Out:
# _id                    object
# listing_url            object
# name                   object
# property_type          object
# room_type              object
# bed_type               object
# minimum_nights          int64
# maximum_nights          int64
# cancellation_policy    object
# accommodates            int64
# bedrooms                int64
# beds                    int64
# number_of_reviews       int64
# bathrooms               int64
# price                   int64
# cleaning_fee            int64
# extra_people            int64
# guests_included         int64
# images                 object
# review_scores           int64
# dtype: object

# %% [markdown]
# ## COLLECTING THE HOST DETAILS

# %%
host= []
for i in coll.find({},{"_id":1, "host":1}):
    host.append(i)

# %%
host

# %%
df_host= pd.DataFrame(host)

# %%
host_columns= {'_id':[],'host_id':[], 'host_url':[], 'host_name':[], 'host_location':[],"host_response_time":[], 'host_thumbnail_url':[], 'host_picture_url':[], 'host_neighbourhood':[], 'host_response_rate':[], 'host_is_superhost':[], 'host_has_profile_pic':[], 'host_identity_verified':[], 'host_listings_count':[], 'host_total_listings_count':[], 'host_verifications':[]}

for i in df_host["_id"]:
    host_columns["_id"].append(i)
for i in df_host["host"]:
    host_columns["host_id"].append(i["host_id"])
    host_columns["host_url"].append(i["host_url"])
    host_columns["host_name"].append(i["host_name"])
    host_columns["host_location"].append(i["host_location"])
    host_columns["host_response_time"].append(i.get("host_response_time"))
    host_columns["host_thumbnail_url"].append(i["host_thumbnail_url"])
    host_columns["host_picture_url"].append(i["host_picture_url"])
    host_columns["host_neighbourhood"].append(i["host_neighbourhood"])
    host_columns["host_response_rate"].append(i.get("host_response_rate"))
    host_columns["host_is_superhost"].append(i["host_is_superhost"])
    host_columns["host_has_profile_pic"].append(i["host_has_profile_pic"])
    host_columns["host_identity_verified"].append(i["host_identity_verified"])
    host_columns["host_listings_count"].append(i["host_listings_count"])
    host_columns["host_total_listings_count"].append(i["host_total_listings_count"])
    host_columns["host_verifications"].append(i["host_verifications"])

# %%
df_host_1= pd.DataFrame(host_columns)

# %%
df_host_1.head(2)
# Out:
#         _id   host_id                                    host_url   host_name  \
# 0  10083468  27518920  https://www.airbnb.com/users/show/27518920       Fábio
# 1  10057447  51612949  https://www.airbnb.com/users/show/51612949  Konstantin
#
#                            host_location host_response_time  \
# 0  São Félix da Marinha, Porto, Portugal     within an hour
# 1               Montreal, Quebec, Canada               None
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/pictures/user/30283...
# 1  https://a0.muscache.com/im/pictures/beb6b50e-0...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/pictures/user/30283...
# 1  https://a0.muscache.com/im/pictures/beb6b50e-0...           Mile End
#
#    host_response_rate  host_is_superhost  host_has_profile_pic  \
# 0                90.0               True                  True
# 1                 NaN              False                  True
#
#    host_identity_verified  host_listings_count  host_total_listings_count  \
# 0                    True                    3                          3
# 1                   False                    1                          1
#
#                                   host_verifications
# 0  [email, phone, reviews, manual_offline, jumio,...
# 1  [email, phone, jumio, offline_government_id, s...

# %%
df_host_1.isnull().sum()
# Out:
# _id                             0
# host_id                         0
# host_url                        0
# host_name                       0
# host_location                   0
# host_response_time           1388
# host_thumbnail_url              0
# host_picture_url                0
# host_neighbourhood              0
# host_response_rate           1388
# host_is_superhost               0
# host_has_profile_pic            0
# host_identity_verified          0
# host_listings_count             0
# host_total_listings_count       0
# host_verifications              0
# dtype: int64

# %% [markdown]
# ## Checking the "host_neighbourhood" details

# %%
# host_neighbourhood have more empty values ('')
# Finding the how many values are empty
list_index= []
for index,row in df_host_1.iterrows():
    if row["host_neighbourhood"] =='':
        list_index.append(index)

# %%
len(list_index)
# Out:
# 1923

# %% [markdown]
# ## Handling the Null values and empty values for "host"

# %%
df_host_1["host_response_time"].fillna("Not Specified",inplace= True)
df_host_1["host_response_rate"].fillna("Not Specified",inplace= True)
df_host_1["host_neighbourhood"]= df_host_1["host_neighbourhood"].replace({'':"Not Specified"})

# %%
df_host_1.isnull().sum()
# Out:
# _id                          0
# host_id                      0
# host_url                     0
# host_name                    0
# host_location                0
# host_response_time           0
# host_thumbnail_url           0
# host_picture_url             0
# host_neighbourhood           0
# host_response_rate           0
# host_is_superhost            0
# host_has_profile_pic         0
# host_identity_verified       0
# host_listings_count          0
# host_total_listings_count    0
# host_verifications           0
# dtype: int64

# %%
df_host_1
# Out:
#            _id   host_id                                    host_url  \
# 0     10083468  27518920  https://www.airbnb.com/users/show/27518920
# 1     10057447  51612949  https://www.airbnb.com/users/show/51612949
# 2     10006546  51399391  https://www.airbnb.com/users/show/51399391
# 3     10030955  51496939  https://www.airbnb.com/users/show/51496939
# 4     10051164  51326285  https://www.airbnb.com/users/show/51326285
# ...        ...       ...                                         ...
# 5550   9703075  38014669  https://www.airbnb.com/users/show/38014669
# 5551   9733671  50223046  https://www.airbnb.com/users/show/50223046
# 5552   9795621  18967737  https://www.airbnb.com/users/show/18967737
# 5553   9936016  47092481  https://www.airbnb.com/users/show/47092481
# 5554   9951865  51142039  https://www.airbnb.com/users/show/51142039
#
#         host_name                                    host_location  \
# 0           Fábio            São Félix da Marinha, Porto, Portugal
# 1      Konstantin                         Montreal, Quebec, Canada
# 2     Ana&Gonçalo                  Porto, Porto District, Portugal
# 3           Livia                                               BR
# 4         Beatriz  Rio de Janeiro, State of Rio de Janeiro, Brazil
# ...           ...                                              ...
# 5550    Stephanie                New York, New York, United States
# 5551       Gaëtan                                               BR
# 5552  Julio Cesar           Rio de Janeiro, Rio de Janeiro, Brazil
# 5553       Aliane                                               BR
# 5554      Dailton  Rio de Janeiro, State of Rio de Janeiro, Brazil
#
#       host_response_time                                 host_thumbnail_url  \
# 0         within an hour  https://a0.muscache.com/im/pictures/user/30283...
# 1          Not Specified  https://a0.muscache.com/im/pictures/beb6b50e-0...
# 2         within an hour  https://a0.muscache.com/im/pictures/fab79f25-2...
# 3          Not Specified  https://a0.muscache.com/im/pictures/b7911710-9...
# 4         within an hour  https://a0.muscache.com/im/pictures/eb09c9cb-b...
# ...                  ...                                                ...
# 5550      within an hour  https://a0.muscache.com/im/users/38014669/prof...
# 5551       Not Specified  https://a0.muscache.com/im/pictures/912e278d-9...
# 5552      within an hour  https://a0.muscache.com/im/pictures/user/55c51...
# 5553       Not Specified  https://a0.muscache.com/im/pictures/4b17fc8e-4...
# 5554  within a few hours  https://a0.muscache.com/im/pictures/user/ad3e9...
#
#                                        host_picture_url host_neighbourhood  \
# 0     https://a0.muscache.com/im/pictures/user/30283...      Not Specified
# 1     https://a0.muscache.com/im/pictures/beb6b50e-0...           Mile End
# 2     https://a0.muscache.com/im/pictures/fab79f25-2...      Not Specified
# 3     https://a0.muscache.com/im/pictures/b7911710-9...              Lagoa
# 4     https://a0.muscache.com/im/pictures/eb09c9cb-b...             Catete
# ...                                                 ...                ...
# 5550  https://a0.muscache.com/im/users/38014669/prof...           Bushwick
# 5551  https://a0.muscache.com/im/pictures/912e278d-9...         Copacabana
# 5552  https://a0.muscache.com/im/pictures/user/55c51...      Not Specified
# 5553  https://a0.muscache.com/im/pictures/4b17fc8e-4...      Not Specified
# 5554  https://a0.muscache.com/im/pictures/user/ad3e9...       Rio Comprido
#
#      host_response_rate  host_is_superhost  host_has_profile_pic  \
# 0                  90.0               True                  True
# 1         Not Specified              False                  True
# 2                 100.0              False                  True
# 3         Not Specified              False                  True
# 4                  80.0              False                  True
# ...                 ...                ...                   ...
# 5550              100.0              False                  True
# 5551      Not Specified              False                  True
# 5552              100.0              False                  True
# 5553      Not Specified              False                  True
# 5554              100.0              False                  True
#
#       host_identity_verified  host_listings_count  host_total_listings_count  \
# 0                       True                    3                          3
# 1                      False                    1                          1
# 2                       True                    3                          3
# 3                      False                    1                          1
# 4                       True                    5                          5
# ...                      ...                  ...                        ...
# 5550                   False                    1                          1
# 5551                   False                    1                          1
# 5552                    True                    1                          1
# 5553                   False                    1                          1
# 5554                   False                    3                          3
#
#                                      host_verifications
# 0     [email, phone, reviews, manual_offline, jumio,...
# 1     [email, phone, jumio, offline_government_id, s...
# 2     [email, phone, reviews, jumio, offline_governm...
# 3                  [email, phone, jumio, government_id]
# 4     [email, phone, facebook, reviews, jumio, gover...
# ...                                                 ...
# 5550                            [email, phone, reviews]
# 5551                                     [email, phone]
# 5552  [email, phone, facebook, reviews, jumio, gover...
# 5553                                            [phone]
# 5554                            [email, phone, reviews]
#
# [5555 rows x 16 columns]

# %%
# Changing the "True" or "False" features

df_host_1["host_is_superhost"]= df_host_1["host_is_superhost"].map({False: "No", True: "Yes"})
df_host_1["host_has_profile_pic"]= df_host_1["host_has_profile_pic"].map({False: "No", True: "Yes"})
df_host_1["host_identity_verified"]= df_host_1["host_identity_verified"].map({False: "No", True: "Yes"})

# %%
df_host_1.head()
# Out:
#         _id   host_id                                    host_url  \
# 0  10083468  27518920  https://www.airbnb.com/users/show/27518920
# 1  10057447  51612949  https://www.airbnb.com/users/show/51612949
# 2  10006546  51399391  https://www.airbnb.com/users/show/51399391
# 3  10030955  51496939  https://www.airbnb.com/users/show/51496939
# 4  10051164  51326285  https://www.airbnb.com/users/show/51326285
#
#      host_name                                    host_location  \
# 0        Fábio            São Félix da Marinha, Porto, Portugal
# 1   Konstantin                         Montreal, Quebec, Canada
# 2  Ana&Gonçalo                  Porto, Porto District, Portugal
# 3        Livia                                               BR
# 4      Beatriz  Rio de Janeiro, State of Rio de Janeiro, Brazil
#
#   host_response_time                                 host_thumbnail_url  \
# 0     within an hour  https://a0.muscache.com/im/pictures/user/30283...
# 1      Not Specified  https://a0.muscache.com/im/pictures/beb6b50e-0...
# 2     within an hour  https://a0.muscache.com/im/pictures/fab79f25-2...
# 3      Not Specified  https://a0.muscache.com/im/pictures/b7911710-9...
# 4     within an hour  https://a0.muscache.com/im/pictures/eb09c9cb-b...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/pictures/user/30283...      Not Specified
# 1  https://a0.muscache.com/im/pictures/beb6b50e-0...           Mile End
# 2  https://a0.muscache.com/im/pictures/fab79f25-2...      Not Specified
# 3  https://a0.muscache.com/im/pictures/b7911710-9...              Lagoa
# 4  https://a0.muscache.com/im/pictures/eb09c9cb-b...             Catete
#
#   host_response_rate host_is_superhost host_has_profile_pic  \
# 0               90.0               Yes                  Yes
# 1      Not Specified                No                  Yes
# 2              100.0                No                  Yes
# 3      Not Specified                No                  Yes
# 4               80.0                No                  Yes
#
#   host_identity_verified  host_listings_count  host_total_listings_count  \
# 0                    Yes                    3                          3
# 1                     No                    1                          1
# 2                    Yes                    3                          3
# 3                     No                    1                          1
# 4                    Yes                    5                          5
#
#                                   host_verifications
# 0  [email, phone, reviews, manual_offline, jumio,...
# 1  [email, phone, jumio, offline_government_id, s...
# 2  [email, phone, reviews, jumio, offline_governm...
# 3               [email, phone, jumio, government_id]
# 4  [email, phone, facebook, reviews, jumio, gover...

# %% [markdown]
# ## Collect the Address Details

# %%
address= []
for i in coll.find({}, {"_id":1, "address":1}):
    address.append(i)

# %%
df_address= pd.DataFrame(address)

# %%
address_columns= {'_id':[], 'street':[], 'suburb':[], 'government_area':[], 'market':[], 'country':[],
                   'country_code':[], 'location_type':[], "longitude":[], "latitude":[],
                    "is_location_exact":[]}

for i in df_address["_id"]:
    address_columns["_id"].append(i)

for i in df_address["address"]:
    address_columns["street"].append(i["street"])
    address_columns["suburb"].append(i["suburb"])
    address_columns["government_area"].append(i["government_area"])
    address_columns["market"].append(i["market"])
    address_columns["country"].append(i["country"])
    address_columns["country_code"].append(i["country_code"])
    address_columns["location_type"].append(i["location"]["type"])
    address_columns["longitude"].append(i["location"]["coordinates"][0])
    address_columns["latitude"].append(i["location"]["coordinates"][1])
    address_columns["is_location_exact"].append(i["location"]["is_location_exact"])

# %%
df_address_1= pd.DataFrame(address_columns)

# %%
df_address_1.head(3)
# Out:
#         _id                    street    suburb  \
# 0  10083468    Porto, Porto, Portugal
# 1  10057447  Montréal, Québec, Canada  Mile End
# 2  10006546    Porto, Porto, Portugal
#
#                                      government_area    market   country  \
# 0  Cedofeita, Ildefonso, Sé, Miragaia, Nicolau, V...     Porto  Portugal
# 1                              Le Plateau-Mont-Royal  Montreal    Canada
# 2  Cedofeita, Ildefonso, Sé, Miragaia, Nicolau, V...     Porto  Portugal
#
#   country_code location_type  longitude  latitude  is_location_exact
# 0           PT         Point   -8.61123  41.15225              False
# 1           CA         Point  -73.59111  45.51889               True
# 2           PT         Point   -8.61308  41.14130              False

# %%
df_address_1.isnull().sum()
# Out:
# _id                  0
# street               0
# suburb               0
# government_area      0
# market               0
# country              0
# country_code         0
# location_type        0
# longitude            0
# latitude             0
# is_location_exact    0
# dtype: int64

# %%
# Checking the empty values ('') for all features

#for i in df_address_1.columns:
id_e=[]
stre_e=[]
suburb_e=[]
gov_e=[]
mark_e=[]
cntry_e=[]
cntry_co_e=[]
loc_ty_e=[]
long_e=[]
lat_e=[]
is_loc_tr_e=[]
for index,row in df_address_1.iterrows():
    if row["_id"] == '':
        id_e.append(index)

    if row["street"] == '':
        stre_e.append(index)
        
    if row["suburb"] == '':
        suburb_e.append(index)

    if row["government_area"] == '':
        gov_e.append(index)

    if row["market"] == '':
        mark_e.append(index)

    if row["country"] == '':
        cntry_e.append(index)
    
    if row["country_code"] == '':
        cntry_co_e.append(index)

    if row["location_type"] == '':
        loc_ty_e.append(index) 

    if row["longitude"] == '':
        long_e.append(index)

    if row["latitude"] == '':
        lat_e.append(index)

    if row["is_location_exact"] == '':
        is_loc_tr_e.append(index)

# %%
empty_columns=[id_e,stre_e,suburb_e,gov_e,mark_e,cntry_e,cntry_co_e,loc_ty_e,long_e,lat_e,is_loc_tr_e]
for i in empty_columns:
    print(len(i))
# Out:
# 0
# 0
# 887
# 0
# 6
# 0
# 0
# 0
# 0
# 0
# 0

# %% [markdown]
# ## Handling the empty values and Boolian Values

# %%
# "suburb" and "market" have a empty values

df_address_1["suburb"]= df_address_1["suburb"].replace({'':"Not Specified"})
df_address_1["market"]= df_address_1["market"].replace({'':"Not Specified"})

df_address_1["is_location_exact"]= df_address_1["is_location_exact"].map({False:"No", True:"Yes"})

# %%
df_address_1
# Out:
#            _id                                           street  \
# 0     10083468                           Porto, Porto, Portugal
# 1     10057447                         Montréal, Québec, Canada
# 2     10006546                           Porto, Porto, Portugal
# 3     10030955           Rio de Janeiro, Rio de Janeiro, Brazil
# 4     10051164           Rio de Janeiro, Rio de Janeiro, Brazil
# ...        ...                                              ...
# 5550   9703075                      Brooklyn, NY, United States
# 5551   9733671           Rio de Janeiro, Rio de Janeiro, Brazil
# 5552   9795621           Rio de Janeiro, Rio de Janeiro, Brazil
# 5553   9936016           Rio de Janeiro, Rio de Janeiro, Brazil
# 5554   9951865  Rio de Janeiro, State of Rio de Janeiro, Brazil
#
#                suburb                                    government_area  \
# 0       Not Specified  Cedofeita, Ildefonso, Sé, Miragaia, Nicolau, V...
# 1            Mile End                              Le Plateau-Mont-Royal
# 2       Not Specified  Cedofeita, Ildefonso, Sé, Miragaia, Nicolau, V...
# 3               Lagoa                                              Lagoa
# 4              Catete                                             Catete
# ...               ...                                                ...
# 5550         Brooklyn                                           Bushwick
# 5551       Copacabana                                         Copacabana
# 5552  Barra da Tijuca                                        Jacarepaguá
# 5553             Lapa                                             Centro
# 5554           Tijuca                                       Rio Comprido
#
#               market        country country_code location_type  longitude  \
# 0              Porto       Portugal           PT         Point  -8.611230
# 1           Montreal         Canada           CA         Point -73.591110
# 2              Porto       Portugal           PT         Point  -8.613080
# 3     Rio De Janeiro         Brazil           BR         Point -43.205047
# 4     Rio De Janeiro         Brazil           BR         Point -43.180157
# ...              ...            ...          ...           ...        ...
# 5550        New York  United States           US         Point -73.920460
# 5551  Rio De Janeiro         Brazil           BR         Point -43.191108
# 5552  Rio De Janeiro         Brazil           BR         Point -43.396270
# 5553  Rio De Janeiro         Brazil           BR         Point -43.173761
# 5554  Rio De Janeiro         Brazil           BR         Point -43.210667
#
#        latitude is_location_exact
# 0     41.152250                No
# 1     45.518890               Yes
# 2     41.141300                No
# 3    -22.971951               Yes
# 4    -22.926382               Yes
# ...         ...               ...
# 5550  40.689960               Yes
# 5551 -22.981273                No
# 5552 -22.971736               Yes
# 5553 -22.908336                No
# 5554 -22.918155                No
#
# [5555 rows x 11 columns]

# %% [markdown]
# ## Availability

# %%
availability= []
for i in coll.find({}, {"_id":1, "availability":1}):
    availability.append(i)

# %%
df_availabe= pd.DataFrame(availability)

# %%
df_availabe
# Out:
#            _id                                       availability
# 0     10083468  {'availability_30': 16, 'availability_60': 40,...
# 1     10057447  {'availability_30': 0, 'availability_60': 0, '...
# 2     10006546  {'availability_30': 28, 'availability_60': 47,...
# 3     10030955  {'availability_30': 28, 'availability_60': 58,...
# 4     10051164  {'availability_30': 10, 'availability_60': 10,...
# ...        ...                                                ...
# 5550   9703075  {'availability_30': 29, 'availability_60': 59,...
# 5551   9733671  {'availability_30': 0, 'availability_60': 0, '...
# 5552   9795621  {'availability_30': 23, 'availability_60': 50,...
# 5553   9936016  {'availability_30': 0, 'availability_60': 0, '...
# 5554   9951865  {'availability_30': 30, 'availability_60': 60,...
#
# [5555 rows x 2 columns]

# %%
availabe_columns= {'_id':[], 'availability_30':[], 'availability_60':[], 'availability_90':[], 'availability_365':[]}

for i in df_availabe["_id"]:
    availabe_columns["_id"].append(i)

for i in df_availabe["availability"]:
    availabe_columns["availability_30"].append(i["availability_30"])
    availabe_columns["availability_60"].append(i["availability_60"])
    availabe_columns["availability_90"].append(i["availability_90"])
    availabe_columns["availability_365"].append(i["availability_365"])

# %%
df_availabe_1= pd.DataFrame(availabe_columns)

# %%
df_availabe_1
# Out:
#            _id  availability_30  availability_60  availability_90  \
# 0     10083468               16               40               67
# 1     10057447                0                0                0
# 2     10006546               28               47               74
# 3     10030955               28               58               88
# 4     10051164               10               10               21
# ...        ...              ...              ...              ...
# 5550   9703075               29               59               89
# 5551   9733671                0                0                0
# 5552   9795621               23               50               64
# 5553   9936016                0                0                0
# 5554   9951865               30               60               90
#
#       availability_365
# 0                  335
# 1                    0
# 2                  239
# 3                  363
# 4                  296
# ...                ...
# 5550               364
# 5551                 0
# 5552               238
# 5553                 0
# 5554               365
#
# [5555 rows x 5 columns]

# %%
df_availabe_1.isnull().sum()
# Out:
# _id                 0
# availability_30     0
# availability_60     0
# availability_90     0
# availability_365    0
# dtype: int64

# %%
df_availabe_1.dtypes
# Out:
# _id                 object
# availability_30      int64
# availability_60      int64
# availability_90      int64
# availability_365     int64
# dtype: object

# %% [markdown]
# ## Collecting the Amenities

# %%
amenities= []
for i in coll.find({},{"_id":1, "amenities":1}):
    amenities.append(i)

# %%
df_amenities= pd.DataFrame(amenities)

# %%
def sort_amenities(x):
    a= x
    a.sort()
    return a

# %%
df_amenities["amenities"]= df_amenities["amenities"].apply(lambda x: sort_amenities(x))

# %%
df_amenities
# Out:
#            _id                                          amenities
# 0     10083468  [Accessible-height bed, Bed linens, Cable TV, ...
# 1     10057447  [24-hour check-in, Dryer, Essentials, Family/k...
# 2     10006546  [Bed linens, Buzzer/wireless intercom, Cable T...
# 3     10030955  [24-hour check-in, Air conditioning, Buzzer/wi...
# 4     10051164  [Air conditioning, Cable TV, Essentials, Famil...
# ...        ...                                                ...
# 5550   9703075  [24-hour check-in, Air conditioning, Bathtub, ...
# 5551   9733671  [Air conditioning, Buzzer/wireless intercom, D...
# 5552   9795621  [Air conditioning, BBQ grill, Bed linens, Cabl...
# 5553   9936016  [Air conditioning, Buzzer/wireless intercom, C...
# 5554   9951865  [Elevator, Essentials, Free street parking, Gy...
#
# [5555 rows x 2 columns]

# %%
df_amenities.isnull().sum()
# Out:
# _id          0
# amenities    0
# dtype: int64

# %%
df_amenities.dtypes
# Out:
# _id          object
# amenities    object
# dtype: object

# %% [markdown]
# ## Merging the All DataFrames

# %%
#df_1
#df_host_1
#df_address_1
#df_availabe_1
#df_amenities
df= pd.merge(df_1, df_host_1, on="_id")
df= pd.merge(df, df_address_1, on="_id")
df= pd.merge(df, df_availabe_1, on="_id")
df= pd.merge(df, df_amenities, on="_id")
